# %%
import csv
import time

from textblob import TextBlob
import nltk
from nltk.stem import WordNetLemmatizer 

from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /home/bence/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Get stopwords
stopwords_eng = stopwords.words('english')
custom_stopwords = ['\'s', '\'ll','br', '1']
# numbers = [i for i in range(10)] 
for word in custom_stopwords:
    stopwords_eng.append(word)

# stopwords_eng

# %%
def lemmatize_with_postag(sentence):
    sent = TextBlob(sentence)
    tag_dict = {"J": 'a', 
                "N": 'n', 
                "V": 'v', 
                "R": 'r'}
    words_and_tags = [(w, tag_dict.get(pos[0], 'n')) for w, pos in sent.tags]    
    lemmatized_list = [wd.lemmatize(tag) for wd, tag in words_and_tags]
    return " ".join(lemmatized_list)

# %%
def read_csv_data(filename):
    # Read the file line by line
    data_file = open(filename, 'r')
    lines = data_file.readlines()
    
    data = []
    with open(filename, newline='\n') as data_file:
        reader = csv.reader(data_file, delimiter=',')
        i = 0
        for row in reader:
            i += 1
            if i == 1:
                continue

            data.append(row)
#     print("Number of rows in dataset = %d" % (i - 1))
    return data

# %%
def build_lexicon_from_csv(filename, nr_of_rows_to_process):
    start_time = time.time()
    
    data = read_csv_data(filename)
    words_dict = {}
    
    i = 0
    for row in data:
        
        if i % 1000 == 0:
            print("Processing row %d" % i)
        
        text = TextBlob(row[0]).lower().words
        polarity = row[1]

        # filter stop words
        filtered_text = [word for word in text if not word in stopwords_eng]

        # lemmatize the text
        lemmatized_filtered_text = TextBlob(lemmatize_with_postag(" ".join(filtered_text)))
  
        for word in lemmatized_filtered_text.words:
            # word is not found in the dictionary
            if word not in words_dict:
                if polarity == 'positive':
                    words_dict[word] = {
                        "pos_count": 1,
                        "neg_count": 0
                    }
                elif polarity == 'negative':
                    words_dict[word] = {
                        "pos_count": 0,
                        "neg_count": 1
                    }
            # word is found in the dictionary
            else:
                if polarity == 'positive':
                    words_dict[word]['pos_count'] +=1
                elif polarity == 'negative':
                    words_dict[word]['neg_count'] +=1
        
        if i == nr_of_rows_to_process:
            print("Processed row %d" % i)
            break
            
        i+=1
                    
    # calculate the polarity of the words
    nr_of_words = 0
    for key, value in words_dict.items():
        neg_count = value['neg_count']
        pos_count = value['pos_count']
        words_dict[key]['polarity'] = pos_count / (neg_count + pos_count)
        
        nr_of_words += 1
        
    print("There are %d words in this sentiment lexicon." % nr_of_words)
    
    finish_time = time.time()
    exec_time = finish_time - start_time
    print("Executed in %s seconds" % exec_time)
    
    return words_dict

# %%
# sentiment_lexicon = build_lexicon_from_csv('IMDB_data_first100row')
sentiment_lexicon = build_lexicon_from_csv('IMDB Dataset.csv', 48000)
# Out:
# Processing row 0
# Processing row 1000
# Processing row 2000
# Processing row 3000
# Processing row 4000
# Processing row 5000
# Processing row 6000
# Processing row 7000
# Processing row 8000
# Processing row 9000
# Processing row 10000
# Processing row 11000
# Processing row 12000
# Processing row 13000
# Processing row 14000
# Processing row 15000
# Processing row 16000
# Processing row 17000
# Processing row 18000
# Processing row 19000
# Processing row 20000
# Processing row 21000
# Processing row 22000
# Processing row 23000
# Processing row 24000
# Processing row 25000
# Processing row 26000
# Processing row 27000
# Processing row 28000
# Processing row 29000
# Processing row 30000
# Processing row 31000
# Processing row 32000
# Processing row 33000
# Processing row 34000
# Processing row 35000
# Processing row 36000
# Processing row 37000
# Processing row 38000
# Processing row 39000
# Processing row 40000
# Processing row 41000
# Processing row 42000
# Processing row 43000
# Processing row 44000
# Processing row 45000
# Processing row 46000
# Processing row 47000
# Processing row 48000
# Processed row 48000
# There are 134638 words in this sentiment lexicon.
# Executed in 489.3751301765442 seconds

# %% [markdown]
# ## Polarity explainer
#
# * 1.0  -> positive
# * 0.5 -> neutral
# * 0.0  -> negative

# %%
sentiment_lexicon
# Out:
# {'one': {'neg_count': 25330,
#   'polarity': 0.5119836621454994,
#   'pos_count': 26574},
#  'reviewer': {'neg_count': 501,
#   'polarity': 0.44884488448844884,
#   'pos_count': 408},
#  'mention': {'neg_count': 1641,
#   'polarity': 0.4256212810640532,
#   'pos_count': 1216},
#  'watch': {'neg_count': 13538,
#   'polarity': 0.46407505641106844,
#   'pos_count': 11723},
#  'oz': {'neg_count': 83, 'polarity': 0.6807692307692308, 'pos_count': 177},
#  'episode': {'neg_count': 1613,
#   'polarity': 0.63013070396698,
#   'pos_count': 2748},
#  'hook': {'neg_count': 187, 'polarity': 0.5862831858407079, 'pos_count': 265},
#  'right': {'neg_count': 3188,
#   'polarity': 0.5124636794616914,
#   'pos_count': 3351},
#  'exactly': {'neg_count': 1005,
#   'polarity': 0.46712619300106045,
#   'pos_count': 881},
#  'happen': {'neg_count': 3488,
#   'polarity': 0.44200927851543753,
#   'pos_count': 2763},
#  'first': {'neg_count': 7861,
#   'polarity': 0.5240949267465795,
#   'pos_count': 8657},
#  'thing': {'neg_count': 9040,
#   'polarity': 0.42795671707903565,
#   'pos_count': 6763},
#  'strike': {'neg_count': 315,
#   'polarity': 0.6139705882352942,
#   'pos_count': 501},
#  'brutality': {'neg_count': 44,
#   'polarity': 0.6764705882352942,
#   'pos_count': 92},
#  'unflinching': {'neg_count': 5,
#   'polarity': 0.8387096774193549,
#   'pos_count': 26},
#  'scene': {'neg_count': 10544,
#   'polarity': 0.46951096800160996,
#   'pos_count': 9332},
#  'violence': {'neg_count': 982,
#   'polarity': 0.5027848101265823,
#   'pos_count': 993},
#  'set': {'neg_count': 3230, 'polarity': 0.5326967592592593, 'pos_count': 3682},
#  'word': {'neg_count': 1852,
#   'polarity': 0.4705546026300743,
#   'pos_count': 1646},
#  'go': {'neg_count': 14122,
#   'polarity': 0.4579302932596346,
#   'pos_count': 11930},
#  'trust': {'neg_count': 324, 'polarity': 0.5283842794759825, 'pos_count': 363},
#  'show': {'neg_count': 9214,
#   'polarity': 0.5553088803088803,
#   'pos_count': 11506},
#  'faint': {'neg_count': 59, 'polarity': 0.49137931034482757, 'pos_count': 57},
#  'hearted': {'neg_count': 47, 'polarity': 0.6209677419354839, 'pos_count': 77},
#  'timid': {'neg_count': 15, 'polarity': 0.6666666666666666, 'pos_count': 30},
#  'pull': {'neg_count': 839, 'polarity': 0.517816091954023, 'pos_count': 901},
#  'punch': {'neg_count': 261,
#   'polarity': 0.47695390781563124,
#   'pos_count': 238},
#  'regard': {'neg_count': 391,
#   'polarity': 0.5591882750845547,
#   'pos_count': 496},
#  'drug': {'neg_count': 792, 'polarity': 0.5068493150684932, 'pos_count': 814},
#  'sex': {'neg_count': 1877, 'polarity': 0.3968508997429306, 'pos_count': 1235},
#  'hardcore': {'neg_count': 113,
#   'polarity': 0.4669811320754717,
#   'pos_count': 99},
#  'classic': {'neg_count': 1357,
#   'polarity': 0.6482633488854329,
#   'pos_count': 2501},
#  'use': {'neg_count': 4709,
#   'polarity': 0.48035753696755684,
#   'pos_count': 4353},
#  'call': {'neg_count': 2997,
#   'polarity': 0.4252013808975834,
#   'pos_count': 2217},
#  'nickname': {'neg_count': 32,
#   'polarity': 0.5844155844155844,
#   'pos_count': 45},
#  'give': {'neg_count': 8401,
#   'polarity': 0.4957080256918182,
#   'pos_count': 8258},
#  'oswald': {'neg_count': 7, 'polarity': 0.78125, 'pos_count': 25},
#  'maximum': {'neg_count': 55, 'polarity': 0.45, 'pos_count': 45},
#  'security': {'neg_count': 214,
#   'polarity': 0.403899721448468,
#   'pos_count': 145},
#  'state': {'neg_count': 933, 'polarity': 0.521047227926078, 'pos_count': 1015},
#  'penitentary': {'neg_count': 0, 'polarity': 1.0, 'pos_count': 2},
#  'focus': {'neg_count': 718, 'polarity': 0.5815850815850816, 'pos_count': 998},
#  'mainly': {'neg_count': 345,
#   'polarity': 0.5369127516778524,
#   'pos_count': 400},
#  'emerald': {'neg_count': 4, 'polarity': 0.7142857142857143, 'pos_count': 10},
#  'city': {'neg_count': 847, 'polarity': 0.6429173693086003, 'pos_count': 1525},
#  'experimental': {'neg_count': 73,
#   'polarity': 0.546583850931677,
#   'pos_count': 88},
#  'section': {'neg_count': 214,
#   'polarity': 0.5169300225733634,
#   'pos_count': 229},
#  'prison': {'neg_count': 430,
#   'polarity': 0.5396145610278372,
#   'pos_count': 504},
#  'cell': {'neg_count': 223, 'polarity': 0.5033407572383074, 'pos_count': 226},
#  'glass': {'neg_count': 218, 'polarity': 0.5429769392033543, 'pos_count': 259},
#  'front': {'neg_count': 639, 'polarity': 0.4625735912531539, 'pos_count': 550},
#  'face': {'neg_count': 1971,
#   'polarity': 0.5162002945508101,
#   'pos_count': 2103},
#  'inwards': {'neg_count': 1, 'polarity': 0.5, 'pos_count': 1},
#  'privacy': {'neg_count': 9, 'polarity': 0.6086956521739131, 'pos_count': 14},
#  'high': {'neg_count': 2087,
#   'polarity': 0.5126109294722092,
#   'pos_count': 2195},
#  'agenda': {'neg_count': 107, 'polarity': 0.3850574712643678, 'pos_count': 67},
#  'em': {'neg_count': 22, 'polarity': 0.6764705882352942, 'pos_count': 46},
#  'home': {'neg_count': 1521,
#   'polarity': 0.5745454545454546,
#   'pos_count': 2054},
#  'many': {'neg_count': 5599, 'polarity': 0.566640866873065, 'pos_count': 7321},
#  'aryan': {'neg_count': 5, 'polarity': 0.8275862068965517, 'pos_count': 24},
#  'muslim': {'neg_count': 84, 'polarity': 0.5307262569832403, 'pos_count': 95},
#  'gangstas': {'neg_count': 0, 'polarity': 1.0, 'pos_count': 2},
#  'latinos': {'neg_count': 13, 'polarity': 0.38095238095238093, 'pos_count': 8},
#  'christian': {'neg_count': 509,
#   'polarity': 0.34491634491634493,
#   'pos_count': 268},
#  'italian': {'neg_count': 479,
#   'polarity': 0.5633546034639927,
#   'pos_count': 618},
#  'irish': {'neg_count': 162, 'polarity': 0.5573770491803278, 'pos_count': 204},
#  'scuffle': {'neg_count': 8, 'polarity': 0.5555555555555556, 'pos_count': 10},
#  'death': {'neg_count': 1882,
#   'polarity': 0.5312577833125778,
#   'pos_count': 2133},
#  'stare': {'neg_count': 119, 'polarity': 0.33519553072625696, 'pos_count': 60},
#  'dodgy': {'neg_count': 59, 'polarity': 0.313953488372093, 'pos_count': 27},
#  'dealing': {'neg_count': 20, 'polarity': 0.5454545454545454, 'pos_count': 24},
#  'shady': {'neg_count': 28, 'polarity': 0.6056338028169014, 'pos_count': 43},
#  'agreement': {'neg_count': 19,
#   'polarity': 0.7466666666666667,
#   'pos_count': 56},
#  'never': {'neg_count': 6385,
#   'polarity': 0.4863647333279704,
#   'pos_count': 6046},
#  'far': {'neg_count': 3103,
#   'polarity': 0.44400645045690734,
#   'pos_count': 2478},
#  'away': {'neg_count': 2760,
#   'polarity': 0.4733829421866056,
#   'pos_count': 2481},
#  'would': {'neg_count': 14642,
#   'polarity': 0.424268637936458,
#   'pos_count': 10790},
#  'say': {'neg_count': 10271,
#   'polarity': 0.4451107509454349,
#   'pos_count': 8239},
#  'main': {'neg_count': 2348,
#   'polarity': 0.46331428571428573,
#   'pos_count': 2027},
#  'appeal': {'neg_count': 637,
#   'polarity': 0.5081081081081081,
#   'pos_count': 658},
#  'due': {'neg_count': 800, 'polarity': 0.5343422584400466, 'pos_count': 918},
#  'fact': {'neg_count': 3743,
#   'polarity': 0.4627529783263959,
#   'pos_count': 3224},
#  "n't": {'neg_count': 38093,
#   'polarity': 0.40167436308233595,
#   'pos_count': 25573},
#  'dare': {'neg_count': 237, 'polarity': 0.5856643356643356, 'pos_count': 335},
#  'forget': {'neg_count': 1026,
#   'polarity': 0.5174035747883349,
#   'pos_count': 1100},
#  'pretty': {'neg_count': 4097,
#   'polarity': 0.4129531451497349,
#   'pos_count': 2882},
#  'picture': {'neg_count': 1563,
#   'polarity': 0.5684704583103258,
#   'pos_count': 2059},
#  'paint': {'neg_count': 438,
#   'polarity': 0.43556701030927836,
#   'pos_count': 338},
#  'mainstream': {'neg_count': 124,
#   'polarity': 0.6565096952908587,
#   'pos_count': 237},
#  'audience': {'neg_count': 2528,
#   'polarity': 0.49165493665795296,
#   'pos_count': 2445},
#  'charm': {'neg_count': 551,
#   'polarity': 0.6596664607782582,
#   'pos_count': 1068},
#  'romance': {'neg_count': 505,
#   'polarity': 0.6359048305695746,
#   'pos_count': 882},
#  'mess': {'neg_count': 1146, 'polarity': 0.1952247191011236, 'pos_count': 278},
#  'around': {'neg_count': 3684,
#   'polarity': 0.457197583615736,
#   'pos_count': 3103},
#  'ever': {'neg_count': 6212,
#   'polarity': 0.4525425222525778,
#   'pos_count': 5135},
#  'saw': {'neg_count': 2723, 'polarity': 0.5475992689815584, 'pos_count': 3296},
#  'struck': {'neg_count': 33, 'polarity': 0.5540540540540541, 'pos_count': 41},
#  'nasty': {'neg_count': 364, 'polarity': 0.4459665144596651, 'pos_count': 293},
#  'surreal': {'neg_count': 126,
#   'polarity': 0.7021276595744681,
#   'pos_count': 297},
#  'could': {'neg_count': 10889,
#   'polarity': 0.38719117564297373,
#   'pos_count': 6880},
#  'ready': {'neg_count': 311, 'polarity': 0.5140625, 'pos_count': 329},
#  'developed': {'neg_count': 65, 'polarity': 0.4921875, 'pos_count': 63},
#  'taste': {'neg_count': 502,
#   'polarity': 0.49190283400809715,
#   'pos_count': 486},
#  'get': {'neg_count': 18491,
#   'polarity': 0.45294517913671195,
#   'pos_count': 15310},
#  'accustomed': {'neg_count': 7,
#   'polarity': 0.6666666666666666,
#   'pos_count': 14},
#  'level': {'neg_count': 1074,
#   'polarity': 0.510036496350365,
#   'pos_count': 1118},
#  'graphic': {'neg_count': 322,
#   'polarity': 0.5582990397805213,
#   'pos_count': 407},
#  'injustice': {'neg_count': 37,
#   'polarity': 0.6574074074074074,
#   'pos_count': 71},
#  'crook': {'neg_count': 89, 'polarity': 0.586046511627907, 'pos_count': 126},
#  'guard': {'neg_count': 273, 'polarity': 0.4625984251968504, 'pos_count': 235},
#  'sell': {'neg_count': 499, 'polarity': 0.5145914396887159, 'pos_count': 529},
#  'nickel': {'neg_count': 4, 'polarity': 0.6923076923076923, 'pos_count': 9},
#  'inmate': {'neg_count': 45, 'polarity': 0.6052631578947368, 'pos_count': 69},
#  'kill': {'neg_count': 4240,
#   'polarity': 0.37231680236861586,
#   'pos_count': 2515},
#  'order': {'neg_count': 1082,
#   'polarity': 0.5143626570915619,
#   'pos_count': 1146},
#  'well': {'neg_count': 11265,
#   'polarity': 0.550801499322115,
#   'pos_count': 13813},
#  'mannered': {'neg_count': 28, 'polarity': 0.5, 'pos_count': 28},
#  'middle': {'neg_count': 830, 'polarity': 0.448871181938911, 'pos_count': 676},
#  'class': {'neg_count': 738, 'polarity': 0.5355569540591567, 'pos_count': 851},
#  'turn': {'neg_count': 3582,
#   'polarity': 0.48718682891911236,
#   'pos_count': 3403},
#  'bitch': {'neg_count': 97, 'polarity': 0.3310344827586207, 'pos_count': 48},
#  'lack': {'neg_count': 2272,
#   'polarity': 0.33176470588235296,
#   'pos_count': 1128},
#  'street': {'neg_count': 701,
#   'polarity': 0.5814925373134329,
#   'pos_count': 974},
#  'skill': {'neg_count': 386, 'polarity': 0.5120101137800253, 'pos_count': 405},
#  'experience': {'neg_count': 1049,
#   'polarity': 0.6357638888888889,
#   'pos_count': 1831},
#  'may': {'neg_count': 2658, 'polarity': 0.5782960495002379, 'pos_count': 3645},
#  'become': {'neg_count': 2699,
#   'polarity': 0.570837971060582,
#   'pos_count': 3590},
#  'comfortable': {'neg_count': 68,
#   'polarity': 0.6936936936936937,
#   'pos_count': 154},
#  'uncomfortable': {'neg_count': 145,
#   'polarity': 0.44866920152091255,
#   'pos_count': 118},
#  'view': {'neg_count': 1468,
#   'polarity': 0.6054823972050524,
#   'pos_count': 2253},
#  'thats': {'neg_count': 394, 'polarity': 0.384375, 'pos_count': 246},
#  'touch': {'neg_count': 597,
#   'polarity': 0.7286363636363636,
#   'pos_count': 1603},
#  'darker': {'neg_count': 39, 'polarity': 0.7784090909090909, 'pos_count': 137},
#  'side': {'neg_count': 1156,
#   'polarity': 0.5712166172106825,
#   'pos_count': 1540},
#  'wonderful': {'neg_count': 523,
#   'polarity': 0.8296416938110749,
#   'pos_count': 2547},
#  'little': {'neg_count': 5696,
#   'polarity': 0.5200134827673379,
#   'pos_count': 6171},
#  'production': {'neg_count': 1964,
#   'polarity': 0.4657236126224157,
#   'pos_count': 1712},
#  'film': {'neg_count': 42251,
#   'polarity': 0.5316736313555095,
#   'pos_count': 47966},
#  'technique': {'neg_count': 227,
#   'polarity': 0.6003521126760564,
#   'pos_count': 341},
#  'unassuming': {'neg_count': 3,
#   'polarity': 0.8695652173913043,
#   'pos_count': 20},
#  'old-time-bbc': {'neg_count': 0, 'polarity': 1.0, 'pos_count': 1},
#  'fashion': {'neg_count': 400,
#   'polarity': 0.5121951219512195,
#   'pos_count': 420},
#  'comfort': {'neg_count': 71,
#   'polarity': 0.6816143497757847,
#   'pos_count': 152},
#  'sometimes': {'neg_count': 861,
#   'polarity': 0.6107594936708861,
#   'pos_count': 1351},
#  'discomforting': {'neg_count': 4,
#   'polarity': 0.6363636363636364,
#   'pos_count': 7},
#  'sense': {'neg_count': 2433,
#   'polarity': 0.45399461400359065,
#   'pos_count': 2023},
#  'realism': {'neg_count': 179,
#   'polarity': 0.6531007751937985,
#   'pos_count': 337},
#  'entire': {'neg_count': 1602,
#   'polarity': 0.4163934426229508,
#   'pos_count': 1143},
#  'piece': {'neg_count': 2050,
#   'polarity': 0.4469921769625034,
#   'pos_count': 1657},
#  'actor': {'neg_count': 6797,
#   'polarity': 0.4654345261502163,
#   'pos_count': 5918},
#  'extremely': {'neg_count': 1044,
#   'polarity': 0.48823529411764705,
#   'pos_count': 996},
#  'choose': {'neg_count': 591,
#   'polarity': 0.5199025182778229,
#   'pos_count': 640},
#  'michael': {'neg_count': 1053,
#   'polarity': 0.5743734842360549,
#   'pos_count': 1421},
#  'sheen': {'neg_count': 87, 'polarity': 0.5628140703517588, 'pos_count': 112},
#  'polari': {'neg_count': 0, 'polarity': 1.0, 'pos_count': 1},
#  'voice': {'neg_count': 1119,
#   'polarity': 0.5500603136308806,
#   'pos_count': 1368},
#  'pat': {'neg_count': 127, 'polarity': 0.5330882352941176, 'pos_count': 145},
#  'truly': {'neg_count': 1374,
#   'polarity': 0.5846432889963724,
#   'pos_count': 1934},
#  'see': {'neg_count': 18758,
#   'polarity': 0.5249936692833629,
#   'pos_count': 20732},
#  'seamless': {'neg_count': 4, 'polarity': 0.8787878787878788, 'pos_count': 29},
#  'edit': {'neg_count': 1201, 'polarity': 0.377720207253886, 'pos_count': 729},
#  'guided': {'neg_count': 1, 'polarity': 0.6666666666666666, 'pos_count': 2},
#  'reference': {'neg_count': 452,
#   'polarity': 0.49440715883668906,
#   'pos_count': 442},
#  'williams': {'neg_count': 258,
#   'polarity': 0.5536332179930796,
#   'pos_count': 320},
#  'diary': {'neg_count': 43, 'polarity': 0.6386554621848739, 'pos_count': 76},
#  'entry': {'neg_count': 186, 'polarity': 0.5452322738386308, 'pos_count': 223},
#  'worth': {'neg_count': 2081,
#   'polarity': 0.5343477287983889,
#   'pos_count': 2388},
#  'terrificly': {'neg_count': 1, 'polarity': 0.8, 'pos_count': 4},
#  'write': {'neg_count': 4218,
#   'polarity': 0.42012647786637336,
#   'pos_count': 3056},
#  'perform': {'neg_count': 361,
#   'polarity': 0.6219895287958115,
#   'pos_count': 594},
#  'masterful': {'neg_count': 33,
#   'polarity': 0.8186813186813187,
#   'pos_count': 149},
#  'great': {'neg_count': 5429,
#   'polarity': 0.7157145101324816,
#   'pos_count': 13668},
#  'master': {'neg_count': 471,
#   'polarity': 0.6061872909698997,
#   'pos_count': 725},
#  'comedy': {'neg_count': 3014,
#   'polarity': 0.5564385577630611,
#   'pos_count': 3781},
#  'life': {'neg_count': 4731,
#   'polarity': 0.6331989455729571,
#   'pos_count': 8167},
#  'really': {'neg_count': 11830,
#   'polarity': 0.4653590635874723,
#   'pos_count': 10297},
#  'come': {'neg_count': 7695,
#   'polarity': 0.5093413250015941,
#   'pos_count': 7988},
#  'fantasy': {'neg_count': 497,
#   'polarity': 0.5666957279860506,
#   'pos_count': 650},
#  'rather': {'neg_count': 2643,
#   'polarity': 0.47684085510688834,
#   'pos_count': 2409},
#  'traditional': {'neg_count': 115,
#   'polarity': 0.7331786542923434,
#   'pos_count': 316},
#  "'dream": {'neg_count': 2, 'polarity': 0.5, 'pos_count': 2},
#  'remain': {'neg_count': 676,
#   'polarity': 0.5809051456912585,
#   'pos_count': 937},
#  'solid': {'neg_count': 244, 'polarity': 0.7315731573157316, 'pos_count': 665},
#  'disappears': {'neg_count': 29,
#   'polarity': 0.3829787234042553,
#   'pos_count': 18},
#  'play': {'neg_count': 6565,
#   'polarity': 0.5792745449884645,
#   'pos_count': 9039},
#  'knowledge': {'neg_count': 232,
#   'polarity': 0.5695732838589982,
#   'pos_count': 307},
#  'sens': {'neg_count': 46, 'polarity': 0.6101694915254238, 'pos_count': 72},
#  'particularly': {'neg_count': 905,
#   'polarity': 0.5468202303455183,
#   'pos_count': 1092},
#  'concern': {'neg_count': 390,
#   'polarity': 0.5470383275261324,
#   'pos_count': 471},
#  'orton': {'neg_count': 4, 'polarity': 0.7894736842105263, 'pos_count': 15},
#  'halliwell': {'neg_count': 0, 'polarity': 1.0, 'pos_count': 12},
#  'flat': {'neg_count': 746, 'polarity': 0.267909715407262, 'pos_count': 273},
#  'mural': {'neg_count': 6, 'polarity': 0.14285714285714285, 'pos_count': 1},
#  'decorate': {'neg_count': 28, 'polarity': 0.582089552238806, 'pos_count': 39},
#  'every': {'neg_count': 3824,
#   'polarity': 0.49717291255752794,
#   'pos_count': 3781},
#  'surface': {'neg_count': 170,
#   'polarity': 0.6179775280898876,
#   'pos_count': 275},
#  'terribly': {'neg_count': 348,
#   'polarity': 0.29979879275653926,
#   'pos_count': 149},
#  'do': {'neg_count': 2861, 'polarity': 0.5050173010380623, 'pos_count': 2919},
#  'think': {'neg_count': 11048,
#   'polarity': 0.4806562309030226,
#   'pos_count': 10225},
#  'way': {'neg_count': 7917, 'polarity': 0.514055978394304, 'pos_count': 8375},
#  'spend': {'neg_count': 1232,
#   'polarity': 0.3698209718670077,
#   'pos_count': 723},
#  'time': {'neg_count': 14139,
#   'polarity': 0.5187542545949626,
#   'pos_count': 15241},
#  'hot': {'neg_count': 698, 'polarity': 0.45082612116443743, 'pos_count': 573},
#  'summer': {'neg_count': 280,
#   'polarity': 0.6116504854368932,
#   'pos_count': 441},
#  'weekend': {'neg_count': 207,
#   'polarity': 0.4435483870967742,
#   'pos_count': 165},
#  'sit': {'neg_count': 1701, 'polarity': 0.3581132075471698, 'pos_count': 949},
#  'air': {'neg_count': 710, 'polarity': 0.5368558382257013, 'pos_count': 823},
#  'condition': {'neg_count': 190,
#   'polarity': 0.6033402922755741,
#   'pos_count': 289},
#  'theater': {'neg_count': 1037,
#   'polarity': 0.4684777037416709,
#   'pos_count': 914},
#  'light-hearted': {'neg_count': 28,
#   'polarity': 0.768595041322314,
#   'pos_count': 93},
#  'plot': {'neg_count': 8081,
#   'polarity': 0.37117734028480276,
#   'pos_count': 4770},
#  'simplistic': {'neg_count': 113,
#   'polarity': 0.45145631067961167,
#   'pos_count': 93},
#  'dialogue': {'neg_count': 1974,
#   'polarity': 0.3681177976952625,
#   'pos_count': 1150},
#  'witty': {'neg_count': 172, 'polarity': 0.6742424242424242, 'pos_count': 356},
#  'character': {'neg_count': 13630,
#   'polarity': 0.49494200911550007,
#   'pos_count': 13357},
#  'likable': {'neg_count': 289,
#   'polarity': 0.5799418604651163,
#   'pos_count': 399},
#  'even': {'neg_count': 14760,
#   'polarity': 0.39005744039009876,
#   'pos_count': 9439},
#  'bread': {'neg_count': 38, 'polarity': 0.6481481481481481, 'pos_count': 70},
#  'suspect': {'neg_count': 439,
#   'polarity': 0.534957627118644,
#   'pos_count': 505},
#  'serial': {'neg_count': 355,
#   'polarity': 0.5021037868162693,
#   'pos_count': 358},
#  'killer': {'neg_count': 1786,
#   'polarity': 0.37486874343717186,
#   'pos_count': 1071},
#  'disappoint': {'neg_count': 566,
#   'polarity': 0.4645222327341533,
#   'pos_count': 491},
#  'realize': {'neg_count': 1027,
#   'polarity': 0.5295464956481906,
#   'pos_count': 1156},
#  'match': {'neg_count': 533, 'polarity': 0.6190135811293781, 'pos_count': 866},
#  'point': {'neg_count': 4312,
#   'polarity': 0.43053354463814053,
#   'pos_count': 3260},
#  '2': {'neg_count': 2871, 'polarity': 0.341211564938045, 'pos_count': 1487},
#  'risk': {'neg_count': 184, 'polarity': 0.5576923076923077, 'pos_count': 232},
#  'addiction': {'neg_count': 50,
#   'polarity': 0.691358024691358,
#   'pos_count': 112},
#  'proof': {'neg_count': 171, 'polarity': 0.4143835616438356, 'pos_count': 121},
#  'woody': {'neg_count': 169, 'polarity': 0.4634920634920635, 'pos_count': 146},
#  'allen': {'neg_count': 256, 'polarity': 0.5362318840579711, 'pos_count': 296},
#  'still': {'neg_count': 4253,
#   'polarity': 0.5918426103646833,
#   'pos_count': 6167},
#  'fully': {'neg_count': 271, 'polarity': 0.6267217630853994, 'pos_count': 455},
#  'control': {'neg_count': 542,
#   'polarity': 0.5494596841230258,
#   'pos_count': 661},
#  'style': {'neg_count': 1228,
#   'polarity': 0.589983305509182,
#   'pos_count': 1767},
#  'u': {'neg_count': 3077, 'polarity': 0.5827230810957418, 'pos_count': 4297},
#  'grown': {'neg_count': 97, 'polarity': 0.5610859728506787, 'pos_count': 124},
#  'love': {'neg_count': 5048,
#   'polarity': 0.6835109717868338,
#   'pos_count': 10902},
#  "'d": {'neg_count': 2540, 'polarity': 0.4097141529165698, 'pos_count': 1763},
#  'laugh': {'neg_count': 3050,
#   'polarity': 0.4398530762167126,
#   'pos_count': 2395},
#  'comedies': {'neg_count': 5, 'polarity': 0.6153846153846154, 'pos_count': 8},
#  'year': {'neg_count': 4789,
#   'polarity': 0.5984403823578736,
#   'pos_count': 7137},
#  'decade': {'neg_count': 309,
#   'polarity': 0.6053639846743295,
#   'pos_count': 474},
#  "'ve": {'neg_count': 5324, 'polarity': 0.4523760543098128, 'pos_count': 4398},
#  'impress': {'neg_count': 193,
#   'polarity': 0.5739514348785872,
#   'pos_count': 260},
#  'scarlet': {'neg_count': 33, 'polarity': 0.56, 'pos_count': 42},
#  'johanson': {'neg_count': 0, 'polarity': 1.0, 'pos_count': 8},
#  'manage': {'neg_count': 1048,
#   'polarity': 0.46802030456852795,
#   'pos_count': 922},
#  'tone': {'neg_count': 417, 'polarity': 0.5899705014749262, 'pos_count': 600},
#  'sexy': {'neg_count': 394, 'polarity': 0.5548022598870056, 'pos_count': 491},
#  'image': {'neg_count': 671,
#   'polarity': 0.6089743589743589,
#   'pos_count': 1045},
#  'jump': {'neg_count': 609, 'polarity': 0.42601319509896324, 'pos_count': 452},
#  'average': {'neg_count': 768,
#   'polarity': 0.41950113378684806,
#   'pos_count': 555},
#  'spirit': {'neg_count': 485,
#   'polarity': 0.6044045676998369,
#   'pos_count': 741},
#  'young': {'neg_count': 2866,
#   'polarity': 0.6310979534045565,
#   'pos_count': 4903},
#  'woman': {'neg_count': 4312,
#   'polarity': 0.49018680539134546,
#   'pos_count': 4146},
#  'crown': {'neg_count': 55, 'polarity': 0.5925925925925926, 'pos_count': 80},
#  'jewel': {'neg_count': 64, 'polarity': 0.681592039800995, 'pos_count': 137},
#  'career': {'neg_count': 973,
#   'polarity': 0.5304054054054054,
#   'pos_count': 1099},
#  'devil': {'neg_count': 304, 'polarity': 0.4482758620689655, 'pos_count': 247},
#  'wear': {'neg_count': 861, 'polarity': 0.3910891089108911, 'pos_count': 553},
#  'prada': {'neg_count': 8, 'polarity': 0.3333333333333333, 'pos_count': 4},
#  'interest': {'neg_count': 2463,
#   'polarity': 0.46940973718224904,
#   'pos_count': 2179},
#  'superman': {'neg_count': 217,
#   'polarity': 0.4135135135135135,
#   'pos_count': 153},
#  'friend': {'neg_count': 2570,
#   'polarity': 0.5451327433628319,
#   'pos_count': 3080},
#  'basically': {'neg_count': 1088,
#   'polarity': 0.3607520564042303,
#   'pos_count': 614},
#  'family': {'neg_count': 2176,
#   'polarity': 0.6358768406961178,
#   'pos_count': 3800},
#  'boy': {'neg_count': 1640, 'polarity': 0.5508079978088195, 'pos_count': 2011},
#  'jake': {'neg_count': 103, 'polarity': 0.588, 'pos_count': 147},
#  'zombie': {'neg_count': 1359,
#   'polarity': 0.24709141274238228,
#   'pos_count': 446},
#  'closet': {'neg_count': 123,
#   'polarity': 0.43577981651376146,
#   'pos_count': 95},
#  'parent': {'neg_count': 732,
#   'polarity': 0.5726795096322241,
#   'pos_count': 981},
#  'fight': {'neg_count': 1888,
#   'polarity': 0.4838709677419355,
#   'pos_count': 1770},
#  'movie': {'neg_count': 55116,
#   'polarity': 0.4350900928602177,
#   'pos_count': 42450},
#  'slow': {'neg_count': 1161, 'polarity': 0.43310546875, 'pos_count': 887},
#  'soap': {'neg_count': 317, 'polarity': 0.412962962962963, 'pos_count': 223},
#  'opera': {'neg_count': 332, 'polarity': 0.5896168108776267, 'pos_count': 477},
#  'suddenly': {'neg_count': 572,
#   'polarity': 0.41091658084449023,
#   'pos_count': 399},
#  'decides': {'neg_count': 287,
#   'polarity': 0.5348460291734197,
#   'pos_count': 330},
#  'rambo': {'neg_count': 105, 'polarity': 0.19230769230769232, 'pos_count': 25},
#  'ok': {'neg_count': 1414, 'polarity': 0.28259766615931, 'pos_count': 557},
#  "'re": {'neg_count': 4219, 'polarity': 0.4091036414565826, 'pos_count': 2921},
#  'make': {'neg_count': 22731,
#   'polarity': 0.45966054958638397,
#   'pos_count': 19337},
#  'must': {'neg_count': 2884,
#   'polarity': 0.5232269796660605,
#   'pos_count': 3165},
#  'decide': {'neg_count': 1564,
#   'polarity': 0.41488963711185933,
#   'pos_count': 1109},
#  'thriller': {'neg_count': 735,
#   'polarity': 0.5795194508009154,
#   'pos_count': 1013},
#  'drama': {'neg_count': 1000,
#   'polarity': 0.6357012750455373,
#   'pos_count': 1745},
#  'watchable': {'neg_count': 405,
#   'polarity': 0.3017241379310345,
#   'pos_count': 175},
#  'divorce': {'neg_count': 114,
#   'polarity': 0.6148648648648649,
#   'pos_count': 182},
#  'argue': {'neg_count': 206, 'polarity': 0.4900990099009901, 'pos_count': 198},
#  'like': {'neg_count': 22532,
#   'polarity': 0.44983518495910146,
#   'pos_count': 18423},
#  'real': {'neg_count': 4005, 'polarity': 0.539602253132544, 'pos_count': 4694},
#  'totally': {'neg_count': 1544,
#   'polarity': 0.41046200840015273,
#   'pos_count': 1075},
#  'ruin': {'neg_count': 663, 'polarity': 0.3282674772036474, 'pos_count': 324},
#  'expect': {'neg_count': 2486,
#   'polarity': 0.4790444258172674,
#   'pos_count': 2286},
#  'boogeyman': {'neg_count': 31,
#   'polarity': 0.3673469387755102,
#   'pos_count': 18},
#  'similar': {'neg_count': 661,
#   'polarity': 0.5797838525111252,
#   'pos_count': 912},
#  'instead': {'neg_count': 2781,
#   'polarity': 0.3269603097773475,
#   'pos_count': 1351},
#  'meaningless': {'neg_count': 169,
#   'polarity': 0.19523809523809524,
#   'pos_count': 41},
#  'spot': {'neg_count': 456, 'polarity': 0.5393939393939394, 'pos_count': 534},
#  '3': {'neg_count': 1795, 'polarity': 0.3458454810495627, 'pos_count': 949},
#  '10': {'neg_count': 2185, 'polarity': 0.48454824251002593, 'pos_count': 2054},
#  'descent': {'neg_count': 94, 'polarity': 0.4233128834355828, 'pos_count': 69},
#  'dialog': {'neg_count': 1200,
#   'polarity': 0.3395707209686296,
#   'pos_count': 617},
#  'shot': {'neg_count': 2853,
#   'polarity': 0.4329159212880143,
#   'pos_count': 2178},
#  'ignore': {'neg_count': 347,
#   'polarity': 0.48592592592592593,
#   'pos_count': 328},
#  'petter': {'neg_count': 0, 'polarity': 1.0, 'pos_count': 1},
#  'mattei': {'neg_count': 25, 'polarity': 0.5283018867924528, 'pos_count': 28},
#  'money': {'neg_count': 2986,
#   'polarity': 0.3029878618113912,
#   'pos_count': 1298},
#  'visually': {'neg_count': 159,
#   'polarity': 0.6528384279475983,
#   'pos_count': 299},
#  'stunning': {'neg_count': 47,
#   'polarity': 0.7684729064039408,
#   'pos_count': 156},
#  'mr': {'neg_count': 1308, 'polarity': 0.5638546182060686, 'pos_count': 1691},
#  'offer': {'neg_count': 826, 'polarity': 0.5438983986747653, 'pos_count': 985},
#  'vivid': {'neg_count': 47, 'polarity': 0.7539267015706806, 'pos_count': 144},
#  'portrait': {'neg_count': 65,
#   'polarity': 0.7743055555555556,
#   'pos_count': 223},
#  'human': {'neg_count': 1343,
#   'polarity': 0.6155167477812769,
#   'pos_count': 2150},
#  'relation': {'neg_count': 145,
#   'polarity': 0.5809248554913294,
#   'pos_count': 201},
#  'seem': {'neg_count': 7657,
#   'polarity': 0.43369573256415944,
#   'pos_count': 5864},
#  'tell': {'neg_count': 3721,
#   'polarity': 0.5149895724713243,
#   'pos_count': 3951},
#  'power': {'neg_count': 1027,
#   'polarity': 0.5578992681876883,
#   'pos_count': 1296},
#  'success': {'neg_count': 431,
#   'polarity': 0.6278065630397237,
#   'pos_count': 727},
#  'people': {'neg_count': 9152,
#   'polarity': 0.47943802969114385,
#   'pos_count': 8429},
#  'different': {'neg_count': 1654,
#   'polarity': 0.6316258351893096,
#   'pos_count': 2836},
#  'situation': {'neg_count': 952,
#   'polarity': 0.5815384615384616,
#   'pos_count': 1323},
#  'encounter': {'neg_count': 323,
#   'polarity': 0.5687583444592791,
#   'pos_count': 426},
#  'variation': {'neg_count': 69,
#   'polarity': 0.5208333333333334,
#   'pos_count': 75},
#  'arthur': {'neg_count': 179,
#   'polarity': 0.6780575539568345,
#   'pos_count': 377},
#  'schnitzler': {'neg_count': 0, 'polarity': 1.0, 'pos_count': 3},
#  'theme': {'neg_count': 833,
#   'polarity': 0.6375108790252393,
#   'pos_count': 1465},
#  'director': {'neg_count': 4827,
#   'polarity': 0.46307007786429366,
#   'pos_count': 4163},
#  'transfer': {'neg_count': 142,
#   'polarity': 0.5328947368421053,
#   'pos_count': 162},
#  'action': {'neg_count': 3121,
#   'polarity': 0.5137871942670198,
#   'pos_count': 3298},
#  'present': {'neg_count': 944,
#   'polarity': 0.5969257045260461,
#   'pos_count': 1398},
#  'new': {'neg_count': 3330, 'polarity': 0.5740598618572524, 'pos_count': 4488},
#  'york': {'neg_count': 498, 'polarity': 0.6356986100950988, 'pos_count': 869},
#  'meet': {'neg_count': 1275, 'polarity': 0.603298070939639, 'pos_count': 1939},
#  'connect': {'neg_count': 269,
#   'polarity': 0.4735812133072407,
#   'pos_count': 242},
#  'another': {'neg_count': 4276,
#   'polarity': 0.48068982268642213,
#   'pos_count': 3958},
#  'next': {'neg_count': 1728,
#   'polarity': 0.48123686580606423,
#   'pos_count': 1603},
#  'person': {'neg_count': 1659,
#   'polarity': 0.48220973782771537,
#   'pos_count': 1545},
#  'know': {'neg_count': 8895,
#   'polarity': 0.4912491420727522,
#   'pos_count': 8589},
#  'previous': {'neg_count': 553,
#   'polarity': 0.5456039441248973,
#   'pos_count': 664},
#  'contact': {'neg_count': 176,
#   'polarity': 0.5440414507772021,
#   'pos_count': 210},
#  'stylishly': {'neg_count': 12,
#   'polarity': 0.5384615384615384,
#   'pos_count': 14},
#  'sophisticate': {'neg_count': 25,
#   'polarity': 0.6323529411764706,
#   'pos_count': 43},
#  'luxurious': {'neg_count': 14, 'polarity': 0.5625, 'pos_count': 18},
#  'look': {'neg_count': 10896,
#   'polarity': 0.41159952478669404,
#   'pos_count': 7622},
#  'take': {'neg_count': 7983, 'polarity': 0.51729350586528, 'pos_count': 8555},
#  'live': {'neg_count': 2418,
#   'polarity': 0.6133056133056133,
#   'pos_count': 3835},
#  'world': {'neg_count': 2612,
#   'polarity': 0.6355518347983815,
#   'pos_count': 4555},
#  'habitat': {'neg_count': 5, 'polarity': 0.75, 'pos_count': 15},
#  'souls': {'neg_count': 34, 'polarity': 0.6179775280898876, 'pos_count': 55},
#  'stage': {'neg_count': 536, 'polarity': 0.5873749037721324, 'pos_count': 763},
#  'loneliness': {'neg_count': 29,
#   'polarity': 0.8198757763975155,
#   'pos_count': 132},
#  'inhabit': {'neg_count': 81, 'polarity': 0.5, 'pos_count': 81},
#  'big': {'neg_count': 4019,
#   'polarity': 0.49081464588876217,
#   'pos_count': 3874},
#  'best': {'neg_count': 3888,
#   'polarity': 0.6753507014028056,
#   'pos_count': 8088},
#  'place': {'neg_count': 2713,
#   'polarity': 0.5204171822520771,
#   'pos_count': 2944},
#  'find': {'neg_count': 6803,
#   'polarity': 0.5434534594993624,
#   'pos_count': 8098},
#  'sincere': {'neg_count': 62, 'polarity': 0.651685393258427, 'pos_count': 116},
#  'fulfillment': {'neg_count': 14,
#   'polarity': 0.6888888888888889,
#   'pos_count': 31},
#  'discern': {'neg_count': 24, 'polarity': 0.5384615384615384, 'pos_count': 28},
#  'case': {'neg_count': 1692,
#   'polarity': 0.4626865671641791,
#   'pos_count': 1457},
#  'act': {'neg_count': 9451,
#   'polarity': 0.39120072146354035,
#   'pos_count': 6073},
#  'good': {'neg_count': 16197,
#   'polarity': 0.4929722961339803,
#   'pos_count': 15748},
#  'direction': {'neg_count': 1508,
#   'polarity': 0.44640234948604995,
#   'pos_count': 1216},
#  'steve': {'neg_count': 409,
#   'polarity': 0.49066002490660027,
#   'pos_count': 394},
#  'buscemi': {'neg_count': 20, 'polarity': 0.5652173913043478, 'pos_count': 26},
#  'rosario': {'neg_count': 36, 'polarity': 0.4782608695652174, 'pos_count': 33},
#  'dawson': {'neg_count': 64, 'polarity': 0.5761589403973509, 'pos_count': 87},
#  'carol': {'neg_count': 79, 'polarity': 0.6565217391304348, 'pos_count': 151},
#  'kane': {'neg_count': 156, 'polarity': 0.5329341317365269, 'pos_count': 178},
#  'imperioli': {'neg_count': 7,
#   'polarity': 0.6666666666666666,
#   'pos_count': 14},
#  'adrian': {'neg_count': 38, 'polarity': 0.5957446808510638, 'pos_count': 56},
#  'grenier': {'neg_count': 5, 'polarity': 0.375, 'pos_count': 3},
#  'rest': {'neg_count': 2003,
#   'polarity': 0.41209275022013503,
#   'pos_count': 1404},
#  'talented': {'neg_count': 501,
#   'polarity': 0.5282485875706214,
#   'pos_count': 561},
#  'cast': {'neg_count': 3620,
#   'polarity': 0.5488534396809571,
#   'pos_count': 4404},
#  'alive': {'neg_count': 475, 'polarity': 0.5087900723888314, 'pos_count': 492},
#  'wish': {'neg_count': 1152,
#   'polarity': 0.5151515151515151,
#   'pos_count': 1224},
#  'luck': {'neg_count': 218, 'polarity': 0.5219298245614035, 'pos_count': 238},
#  'await': {'neg_count': 61, 'polarity': 0.6139240506329114, 'pos_count': 97},
#  'anxiously': {'neg_count': 11, 'polarity': 0.5, 'pos_count': 11},
#  'work': {'neg_count': 5778,
#   'polarity': 0.5497896213183731,
#   'pos_count': 7056},
#  'probably': {'neg_count': 2831,
#   'polarity': 0.47457312546399405,
#   'pos_count': 2557},
#  'all-time': {'neg_count': 67,
#   'polarity': 0.6794258373205742,
#   'pos_count': 142},
#  'favorite': {'neg_count': 547,
#   'polarity': 0.7748044462741869,
#   'pos_count': 1882},
#  'story': {'neg_count': 10396,
#   'polarity': 0.5615352172079291,
#   'pos_count': 13314},
#  'selflessness': {'neg_count': 1, 'polarity': 0.75, 'pos_count': 3},
#  'sacrifice': {'neg_count': 178,
#   'polarity': 0.531578947368421,
#   'pos_count': 202},
#  'dedication': {'neg_count': 18,
#   'polarity': 0.7804878048780488,
#   'pos_count': 64},
#  'noble': {'neg_count': 90, 'polarity': 0.6414342629482072, 'pos_count': 161},
#  'cause': {'neg_count': 945, 'polarity': 0.4965370271710176, 'pos_count': 932},
#  'preachy': {'neg_count': 70, 'polarity': 0.5, 'pos_count': 70},
#  'bore': {'neg_count': 2315, 'polarity': 0.2071917808219178, 'pos_count': 605},
#  'old': {'neg_count': 4214, 'polarity': 0.5177937979173819, 'pos_count': 4525},
#  'despite': {'neg_count': 1201,
#   'polarity': 0.535036778939218,
#   'pos_count': 1382},
#  '15': {'neg_count': 510, 'polarity': 0.3992932862190813, 'pos_count': 339},
#  'last': {'neg_count': 2723,
#   'polarity': 0.5282397782397782,
#   'pos_count': 3049},
#  '25': {'neg_count': 166, 'polarity': 0.47962382445141066, 'pos_count': 153},
#  'paul': {'neg_count': 516, 'polarity': 0.6301075268817204, 'pos_count': 879},
#  'lukas': {'neg_count': 21, 'polarity': 0.7, 'pos_count': 49},
#  'performance': {'neg_count': 2849,
#   'polarity': 0.6673283512377394,
#   'pos_count': 5715},
#  'bring': {'neg_count': 1598,
#   'polarity': 0.5970751386787695,
#   'pos_count': 2368},
#  'tear': {'neg_count': 297, 'polarity': 0.6785714285714286, 'pos_count': 627},
#  'eye': {'neg_count': 1616, 'polarity': 0.5528500276701716, 'pos_count': 1998},
#  'bette': {'neg_count': 56, 'polarity': 0.7268292682926829, 'pos_count': 149},
#  'davis': {'neg_count': 137, 'polarity': 0.732943469785575, 'pos_count': 376},
#  'sympathetic': {'neg_count': 166,
#   'polarity': 0.621867881548975,
#   'pos_count': 273},
#  'role': {'neg_count': 3033,
#   'polarity': 0.6113033448673587,
#   'pos_count': 4770},
#  'delight': {'neg_count': 90,
#   'polarity': 0.7804878048780488,
#   'pos_count': 320},
#  'kid': {'neg_count': 3183,
#   'polarity': 0.46023401729693064,
#   'pos_count': 2714},
#  'grandma': {'neg_count': 66,
#   'polarity': 0.37735849056603776,
#   'pos_count': 40},
#  'dressed-up': {'neg_count': 0, 'polarity': 1.0, 'pos_count': 1},
#  'midget': {'neg_count': 73, 'polarity': 0.1797752808988764, 'pos_count': 16},
#  'child': {'neg_count': 2293,
#   'polarity': 0.5564796905222437,
#   'pos_count': 2877},
#  'fun': {'neg_count': 1956, 'polarity': 0.6148089799133517, 'pos_count': 3122},
#  'mother': {'neg_count': 1221,
#   'polarity': 0.6037000973709834,
#   'pos_count': 1860},
#  'awaken': {'neg_count': 62, 'polarity': 0.6025641025641025, 'pos_count': 94},
#  'roof': {'neg_count': 62, 'polarity': 0.610062893081761, 'pos_count': 97},
#  'believable': {'neg_count': 513,
#   'polarity': 0.6340941512125535,
#   'pos_count': 889},
#  'startle': {'neg_count': 53, 'polarity': 0.6319444444444444, 'pos_count': 91},
#  'dozen': {'neg_count': 274,
#   'polarity': 0.42071881606765327,
#   'pos_count': 199},
#  'thumb': {'neg_count': 119, 'polarity': 0.5277777777777778, 'pos_count': 133},
#  'sure': {'neg_count': 2664,
#   'polarity': 0.4714285714285714,
#   'pos_count': 2376},
#  'resurrection': {'neg_count': 55,
#   'polarity': 0.22535211267605634,
#   'pos_count': 16},
#  'date': {'neg_count': 628, 'polarity': 0.5662983425414365, 'pos_count': 820},
#  'seahunt': {'neg_count': 0, 'polarity': 1.0, 'pos_count': 2},
#  'series': {'neg_count': 2290,
#   'polarity': 0.62048392442824,
#   'pos_count': 3744},
#  'tech': {'neg_count': 45, 'polarity': 0.45121951219512196, 'pos_count': 37},
#  'today': {'neg_count': 626,
#   'polarity': 0.7434426229508196,
#   'pos_count': 1814},
#  'back': {'neg_count': 4501,
#   'polarity': 0.5144552319309601,
#   'pos_count': 4769},
#  'excitement': {'neg_count': 203,
#   'polarity': 0.48081841432225064,
#   'pos_count': 188},
#  'me.i': {'neg_count': 2, 'polarity': 0.5, 'pos_count': 2},
#  'grow': {'neg_count': 684, 'polarity': 0.6104783599088838, 'pos_count': 1072},
#  'black': {'neg_count': 1972,
#   'polarity': 0.5021459227467812,
#   'pos_count': 1989},
#  'white': {'neg_count': 1264,
#   'polarity': 0.5102673382409919,
#   'pos_count': 1317},
#  'tv': {'neg_count': 2436, 'polarity': 0.518957345971564, 'pos_count': 2628},
#  'gunsmoke': {'neg_count': 4, 'polarity': 0.7777777777777778, 'pos_count': 14},
#  'hero': {'neg_count': 1271,
#   'polarity': 0.4754436648782501,
#   'pos_count': 1152},
#  'week.you': {'neg_count': 0, 'polarity': 1.0, 'pos_count': 1},
#  'vote': {'neg_count': 415, 'polarity': 0.43537414965986393, 'pos_count': 320},
#  'comeback': {'neg_count': 60,
#   'polarity': 0.4827586206896552,
#   'pos_count': 56},
#  'sea': {'neg_count': 284, 'polarity': 0.5499207606973059, 'pos_count': 347},
#  'hunt.we': {'neg_count': 0, 'polarity': 1.0, 'pos_count': 1},
#  'need': {'neg_count': 3307,
#   'polarity': 0.4711338557492404,
#   'pos_count': 2946},
#  'change': {'neg_count': 1718,
#   'polarity': 0.5490813648293963,
#   'pos_count': 2092},
#  'pace': {'neg_count': 797, 'polarity': 0.5630482456140351, 'pos_count': 1027},
#  'water': {'neg_count': 687, 'polarity': 0.5189075630252101, 'pos_count': 741},
#  'adventure.oh': {'neg_count': 0, 'polarity': 1.0, 'pos_count': 1},
#  'thank': {'neg_count': 357, 'polarity': 0.5662211421628189, 'pos_count': 466},
#  'outlet': {'neg_count': 23, 'polarity': 0.5208333333333334, 'pos_count': 25},
#  'viewpoint': {'neg_count': 60,
#   'polarity': 0.5348837209302325,
#   'pos_count': 69},
#  'movies.so': {'neg_count': 0, 'polarity': 1.0, 'pos_count': 1},
#  'ole': {'neg_count': 19, 'polarity': 0.4722222222222222, 'pos_count': 17},
#  'believe': {'neg_count': 3261,
#   'polarity': 0.4385330578512397,
#   'pos_count': 2547},
#  'wan': {'neg_count': 201, 'polarity': 0.3890577507598784, 'pos_count': 128},
#  'na': {'neg_count': 469, 'polarity': 0.36103542234332425, 'pos_count': 265},
#  'say.would': {'neg_count': 0, 'polarity': 1.0, 'pos_count': 1},
#  'nice': {'neg_count': 1646,
#   'polarity': 0.5548945375878853,
#   'pos_count': 2052},
#  'read': {'neg_count': 2606,
#   'polarity': 0.4478813559322034,
#   'pos_count': 2114},
#  'plus': {'neg_count': 646, 'polarity': 0.48195669607056935, 'pos_count': 601},
#  'hunt.if': {'neg_count': 0, 'polarity': 1.0, 'pos_count': 1},
#  'rhyme': {'neg_count': 86, 'polarity': 0.23893805309734514, 'pos_count': 27},
#  'line': {'neg_count': 3558, 'polarity': 0.43072, 'pos_count': 2692},
#  'let': {'neg_count': 3084,
#   'polarity': 0.42312008978675647,
#   'pos_count': 2262},
#  'submit': {'neg_count': 62, 'polarity': 0.4745762711864407, 'pos_count': 56},
#  'leave': {'neg_count': 3827,
#   'polarity': 0.48802675585284283,
#   'pos_count': 3648},
#  'doubt': {'neg_count': 829, 'polarity': 0.4917228694052728, 'pos_count': 802},
#  'quit': {'neg_count': 100, 'polarity': 0.4791666666666667, 'pos_count': 92},
#  'amazing': {'neg_count': 220,
#   'polarity': 0.7849462365591398,
#   'pos_count': 803},
#  'fresh': {'neg_count': 232, 'polarity': 0.6741573033707865, 'pos_count': 480},
#  'innovative': {'neg_count': 78,
#   'polarity': 0.6060606060606061,
#   'pos_count': 120},
#  'idea': {'neg_count': 3128,
#   'polarity': 0.36782538399353276,
#   'pos_count': 1820},
#  '70': {'neg_count': 515, 'polarity': 0.5343580470162749, 'pos_count': 591},
#  '7': {'neg_count': 326, 'polarity': 0.6464208242950108, 'pos_count': 596},
#  '8': {'neg_count': 302, 'polarity': 0.6614349775784754, 'pos_count': 590},
#  'brilliant': {'neg_count': 516,
#   'polarity': 0.774869109947644,
#   'pos_count': 1776},
#  'drop': {'neg_count': 523, 'polarity': 0.42464246424642466, 'pos_count': 386},
#  '1990': {'neg_count': 99, 'polarity': 0.543778801843318, 'pos_count': 118},
#  'funny': {'neg_count': 4635,
#   'polarity': 0.48750552852720036,
#   'pos_count': 4409},
#  'anymore': {'neg_count': 364,
#   'polarity': 0.45752608047690013,
#   'pos_count': 307},
#  'continued': {'neg_count': 15,
#   'polarity': 0.5588235294117647,
#   'pos_count': 19},
#  'decline': {'neg_count': 80, 'polarity': 0.5375722543352601, 'pos_count': 93},
#  'complete': {'neg_count': 1318,
#   'polarity': 0.38439981317141525,
#   'pos_count': 823},
#  'waste': {'neg_count': 3644,
#   'polarity': 0.08602959618760973,
#   'pos_count': 343},
#  'disgraceful': {'neg_count': 33,
#   'polarity': 0.08333333333333333,
#   'pos_count': 3},
#  'fall': {'neg_count': 2061,
#   'polarity': 0.48242089402310395,
#   'pos_count': 1921},
#  'painfully': {'neg_count': 313,
#   'polarity': 0.229064039408867,
#   'pos_count': 93},
#  'bad': {'neg_count': 19496,
#   'polarity': 0.17786961288690226,
#   'pos_count': 4218},
#  'almost': {'neg_count': 3019,
#   'polarity': 0.4937961099932931,
#   'pos_count': 2945},
#  'mildly': {'neg_count': 284, 'polarity': 0.1695906432748538, 'pos_count': 58},
#  'entertaining': {'neg_count': 363,
#   'polarity': 0.5856164383561644,
#   'pos_count': 513},
#  'respite': {'neg_count': 8, 'polarity': 0.6521739130434783, 'pos_count': 15},
#  'guest-hosts': {'neg_count': 1, 'polarity': 0.0, 'pos_count': 0},
#  'hard': {'neg_count': 2531,
#   'polarity': 0.47138680033416874,
#   'pos_count': 2257},
#  'creator': {'neg_count': 207,
#   'polarity': 0.47858942065491183,
#   'pos_count': 190},
#  'hand-selected': {'neg_count': 1, 'polarity': 0.0, 'pos_count': 0},
#  'original': {'neg_count': 3555,
#   'polarity': 0.41807169749549844,
#   'pos_count': 2554},
#  'also': {'neg_count': 6884,
#   'polarity': 0.6006265591460231,
#   'pos_count': 10353},
#  'band': {'neg_count': 477, 'polarity': 0.5812115891132572, 'pos_count': 662},
#  'hack': {'neg_count': 208, 'polarity': 0.2597864768683274, 'pos_count': 73},
#  'follow': {'neg_count': 1776,
#   'polarity': 0.5647058823529412,
#   'pos_count': 2304},
#  'recognize': {'neg_count': 256,
#   'polarity': 0.6156156156156156,
#   'pos_count': 410},
#  'brilliance': {'neg_count': 67,
#   'polarity': 0.70995670995671,
#   'pos_count': 164},
#  'fit': {'neg_count': 669, 'polarity': 0.5736137667304015, 'pos_count': 900},
#  'replace': {'neg_count': 264,
#   'polarity': 0.4567901234567901,
#   'pos_count': 222},
#  'mediocrity': {'neg_count': 82,
#   'polarity': 0.21904761904761905,
#   'pos_count': 23},
#  'felt': {'neg_count': 1526,
#   'polarity': 0.44387755102040816,
#   'pos_count': 1218},
#  'star': {'neg_count': 3682,
#   'polarity': 0.5179366326263419,
#   'pos_count': 3956},
#  'respect': {'neg_count': 520,
#   'polarity': 0.5478260869565217,
#   'pos_count': 630},
#  'huge': {'neg_count': 1011,
#   'polarity': 0.45024469820554647,
#   'pos_count': 828},
#  'awful': {'neg_count': 2902,
#   'polarity': 0.08913998744507219,
#   'pos_count': 284},
#  'ca': {'neg_count': 4033, 'polarity': 0.40856430561665935, 'pos_count': 2786},
#  'encourage': {'neg_count': 121,
#   'polarity': 0.5709219858156028,
#   'pos_count': 161},
#  'positive': {'neg_count': 621, 'polarity': 0.353125, 'pos_count': 339},
#  'comment': {'neg_count': 1559,
#   'polarity': 0.48102529960053264,
#   'pos_count': 1445},
#  'forward': {'neg_count': 697,
#   'polarity': 0.4152684563758389,
#   'pos_count': 495},
#  'mistake': {'neg_count': 718,
#   'polarity': 0.4085667215815486,
#   'pos_count': 496},
#  '950': {'neg_count': 1, 'polarity': 0.0, 'pos_count': 0},
#  'storyline': {'neg_count': 862,
#   'polarity': 0.42724252491694353,
#   'pos_count': 643},
#  "'acting": {'neg_count': 8, 'polarity': 0.38461538461538464, 'pos_count': 5},
#  'soundtrack': {'neg_count': 614,
#   'polarity': 0.6179215930304915,
#   'pos_count': 993},
#  'song': {'neg_count': 1363,
#   'polarity': 0.6052707790327252,
#   'pos_count': 2090},
#  'lame': {'neg_count': 1212,
#   'polarity': 0.11790393013100436,
#   'pos_count': 162},
#  'country': {'neg_count': 803,
#   'polarity': 0.6092457420924574,
#   'pos_count': 1252},
#  'tune': {'neg_count': 251, 'polarity': 0.5891980360065466, 'pos_count': 360},
#  'less': {'neg_count': 1816,
#   'polarity': 0.4641487164355267,
#   'pos_count': 1573},
#  'four': {'neg_count': 831, 'polarity': 0.5146028037383178, 'pos_count': 881},
#  'cheap': {'neg_count': 1390,
#   'polarity': 0.20662100456621005,
#   'pos_count': 362},
#  'boring': {'neg_count': 1392,
#   'polarity': 0.18213866039952997,
#   'pos_count': 310},
#  'extreme': {'neg_count': 333,
#   'polarity': 0.5342657342657343,
#   'pos_count': 382},
#  'rarely': {'neg_count': 256,
#   'polarity': 0.5638841567291312,
#   'pos_count': 331},
#  'happy': {'neg_count': 658,
#   'polarity': 0.6165501165501166,
#   'pos_count': 1058},
#  'end': {'neg_count': 9174, 'polarity': 0.4864819479429051, 'pos_count': 8691},
#  'credit': {'neg_count': 1360,
#   'polarity': 0.4340407823553891,
#   'pos_count': 1043},
#  'prevents': {'neg_count': 28,
#   'polarity': 0.45098039215686275,
#   'pos_count': 23},
#  '1-score': {'neg_count': 1, 'polarity': 0.0, 'pos_count': 0},
#  'harvey': {'neg_count': 77, 'polarity': 0.5523255813953488, 'pos_count': 95},
#  'keitel': {'neg_count': 44, 'polarity': 0.30158730158730157, 'pos_count': 19},
#  'least': {'neg_count': 3813,
#   'polarity': 0.3475359342915811,
#   'pos_count': 2031},
#  'bite': {'neg_count': 428, 'polarity': 0.5097365406643757, 'pos_count': 445},
#  'effort': {'neg_count': 1222,
#   'polarity': 0.39384920634920634,
#   'pos_count': 794},
#  'obsessive': {'neg_count': 28,
#   'polarity': 0.7281553398058253,
#   'pos_count': 75},
#  'gut': {'neg_count': 171, 'polarity': 0.5086206896551724, 'pos_count': 177},
#  'wrench': {'neg_count': 20, 'polarity': 0.7435897435897436, 'pos_count': 58},
#  'laughter': {'neg_count': 225,
#   'polarity': 0.49324324324324326,
#   'pos_count': 219},
#  'hell': {'neg_count': 1269, 'polarity': 0.3512269938650307, 'pos_count': 687},
#  'mom': {'neg_count': 369, 'polarity': 0.4773371104815864, 'pos_count': 337},
#  'liked': {'neg_count': 205, 'polarity': 0.6709470304975923, 'pos_count': 418},
#  'camp': {'neg_count': 524, 'polarity': 0.48977604673807207, 'pos_count': 503},
#  'phil': {'neg_count': 76, 'polarity': 0.5891891891891892, 'pos_count': 109},
#  'alien': {'neg_count': 874, 'polarity': 0.3378787878787879, 'pos_count': 446},
#  'quirky': {'neg_count': 137,
#   'polarity': 0.6096866096866097,
#   'pos_count': 214},
#  'humour': {'neg_count': 382,
#   'polarity': 0.5788313120176406,
#   'pos_count': 525},
#  'base': {'neg_count': 1410,
#   'polarity': 0.5326483261518065,
#   'pos_count': 1607},
#  'oddness': {'neg_count': 10, 'polarity': 0.4117647058823529, 'pos_count': 7},
#  'everything': {'neg_count': 2324,
#   'polarity': 0.49533116178067316,
#   'pos_count': 2281},
#  'actual': {'neg_count': 789,
#   'polarity': 0.4439746300211416,
#   'pos_count': 630},
#  'punchlines': {'neg_count': 18,
#   'polarity': 0.14285714285714285,
#   'pos_count': 3},
#  'odd': {'neg_count': 507, 'polarity': 0.5189753320683111, 'pos_count': 547},
#  'progress': {'neg_count': 180,
#   'polarity': 0.6103896103896104,
#   'pos_count': 282},
#  'jokes': {'neg_count': 6, 'polarity': 0.3333333333333333, 'pos_count': 3},
#  'low': {'neg_count': 2005, 'polarity': 0.32309250506414583, 'pos_count': 957},
#  'budget': {'neg_count': 2051,
#   'polarity': 0.35543683218101824,
#   'pos_count': 1131},
#  'problem': {'neg_count': 2566,
#   'polarity': 0.4128146453089245,
#   'pos_count': 1804},
#  'interesting': {'neg_count': 1814,
#   'polarity': 0.45623501199040767,
#   'pos_count': 1522},
#  'eventually': {'neg_count': 594,
#   'polarity': 0.5606508875739645,
#   'pos_count': 758},
#  'lose': {'neg_count': 1924,
#   'polarity': 0.5251727541954591,
#   'pos_count': 2128},
#  'imagine': {'neg_count': 900,
#   'polarity': 0.44751381215469616,
#   'pos_count': 729},
#  'stoner': {'neg_count': 46, 'polarity': 0.41025641025641024, 'pos_count': 32},
#  'currently': {'neg_count': 103,
#   'polarity': 0.5462555066079295,
#   'pos_count': 124},
#  'partake': {'neg_count': 16, 'polarity': 0.3333333333333333, 'pos_count': 8},
#  'something': {'neg_count': 5556,
#   'polarity': 0.4232925057089475,
#   'pos_count': 4078},
#  'try': {'neg_count': 7019, 'polarity': 0.3965784044016506, 'pos_count': 4613},
#  'brother': {'neg_count': 1206,
#   'polarity': 0.5794979079497908,
#   'pos_count': 1662},
#  'planet': {'neg_count': 418,
#   'polarity': 0.5287485907553551,
#   'pos_count': 469},
#  '12': {'neg_count': 234, 'polarity': 0.5195071868583162, 'pos_count': 253},
#  'recall': {'neg_count': 233,
#   'polarity': 0.5897887323943662,
#   'pos_count': 335},
#  'scary': {'neg_count': 1169,
#   'polarity': 0.3821353065539112,
#   'pos_count': 723},
#  'bird': {'neg_count': 193, 'polarity': 0.5360576923076923, 'pos_count': 223},
# ...
#   'pos_count': 391},
#  'mile': {'neg_count': 355, 'polarity': 0.47794117647058826, 'pos_count': 325},
#  'starve': {'neg_count': 52, 'polarity': 0.4157303370786517, 'pos_count': 37},
#  'aid': {'neg_count': 150, 'polarity': 0.635036496350365, 'pos_count': 261},
#  'africa': {'neg_count': 160, 'polarity': 0.559228650137741, 'pos_count': 203},
#  'simply': {'neg_count': 2118,
#   'polarity': 0.4301856335754641,
#   'pos_count': 1599},
#  'remake': {'neg_count': 799,
#   'polarity': 0.38253477588871715,
#   'pos_count': 495},
#  'fail': {'neg_count': 1657, 'polarity': 0.2677861246133451, 'pos_count': 606},
#  'capture': {'neg_count': 486,
#   'polarity': 0.6870573084352866,
#   'pos_count': 1067},
#  'flavor': {'neg_count': 46, 'polarity': 0.5700934579439252, 'pos_count': 61},
#  'terror': {'neg_count': 208,
#   'polarity': 0.5346756152125279,
#   'pos_count': 239},
#  '1963': {'neg_count': 29, 'polarity': 0.5396825396825397, 'pos_count': 34},
#  'title': {'neg_count': 1818,
#   'polarity': 0.4522446520036155,
#   'pos_count': 1501},
#  'liam': {'neg_count': 28, 'polarity': 0.6056338028169014, 'pos_count': 43},
#  'neeson': {'neg_count': 22, 'polarity': 0.5319148936170213, 'pos_count': 25},
#  'excellent': {'neg_count': 708,
#   'polarity': 0.8196637799286806,
#   'pos_count': 3218},
#  'always': {'neg_count': 2151,
#   'polarity': 0.6429282868525896,
#   'pos_count': 3873},
#  'hold': {'neg_count': 1112,
#   'polarity': 0.5657946114798906,
#   'pos_count': 1449},
#  'exception': {'neg_count': 502,
#   'polarity': 0.4101057579318449,
#   'pos_count': 349},
#  'owen': {'neg_count': 100, 'polarity': 0.5918367346938775, 'pos_count': 145},
#  'wilson': {'neg_count': 162,
#   'polarity': 0.5919395465994962,
#   'pos_count': 235},
#  'luke': {'neg_count': 117, 'polarity': 0.6422018348623854, 'pos_count': 210},
#  'major': {'neg_count': 891, 'polarity': 0.509090909090909, 'pos_count': 924},
#  'fault': {'neg_count': 361, 'polarity': 0.4341692789968652, 'pos_count': 277},
#  'version': {'neg_count': 2010,
#   'polarity': 0.5346144940958555,
#   'pos_count': 2309},
#  'stray': {'neg_count': 59, 'polarity': 0.46846846846846846, 'pos_count': 52},
#  'shirley': {'neg_count': 105,
#   'polarity': 0.43243243243243246,
#   'pos_count': 80},
#  'jackson': {'neg_count': 242,
#   'polarity': 0.6316590563165906,
#   'pos_count': 415},
#  'attempt': {'neg_count': 2378,
#   'polarity': 0.33815752852769276,
#   'pos_count': 1215},
#  'grandiose': {'neg_count': 17,
#   'polarity': 0.5641025641025641,
#   'pos_count': 22},
#  'thrill': {'neg_count': 328,
#   'polarity': 0.5684210526315789,
#   'pos_count': 432},
#  'earlier': {'neg_count': 435,
#   'polarity': 0.5382165605095541,
#   'pos_count': 507},
#  'trade': {'neg_count': 115, 'polarity': 0.5724907063197026, 'pos_count': 154},
#  'snazzier': {'neg_count': 0, 'polarity': 1.0, 'pos_count': 1},
#  'special': {'neg_count': 2202,
#   'polarity': 0.45548961424332346,
#   'pos_count': 1842},
#  'effect': {'neg_count': 3295,
#   'polarity': 0.40275512053652346,
#   'pos_count': 2222},
#  'friction': {'neg_count': 11, 'polarity': 0.56, 'pos_count': 14},
#  'top': {'neg_count': 1369, 'polarity': 0.5620601407549584, 'pos_count': 1757},
#  'horrible': {'neg_count': 2072,
#   'polarity': 0.13450292397660818,
#   'pos_count': 322},
#  'continuous': {'neg_count': 33,
#   'polarity': 0.5416666666666666,
#   'pos_count': 39},
#  'chance': {'neg_count': 909,
#   'polarity': 0.5951002227171492,
#   'pos_count': 1336},
#  'development': {'neg_count': 737,
#   'polarity': 0.3973834832379395,
#   'pos_count': 486},
#  'busy': {'neg_count': 131, 'polarity': 0.5166051660516605, 'pos_count': 140},
#  'run': {'neg_count': 2817,
#   'polarity': 0.44743036484896037,
#   'pos_count': 2281},
#  'sword': {'neg_count': 195,
#   'polarity': 0.45224719101123595,
#   'pos_count': 161},
#  'emotional': {'neg_count': 399,
#   'polarity': 0.6850828729281768,
#   'pos_count': 868},
#  'attachment': {'neg_count': 31,
#   'polarity': 0.4745762711864407,
#   'pos_count': 28},
#  'except': {'neg_count': 1363,
#   'polarity': 0.3627863487611033,
#   'pos_count': 776},
#  'machine': {'neg_count': 424,
#   'polarity': 0.46329113924050636,
#   'pos_count': 366},
#  'want': {'neg_count': 6751,
#   'polarity': 0.45415588615782665,
#   'pos_count': 5617},
#  'destroy': {'neg_count': 582,
#   'polarity': 0.3828207847295864,
#   'pos_count': 361},
#  'blatantly': {'neg_count': 89,
#   'polarity': 0.2457627118644068,
#   'pos_count': 29},
#  'steal': {'neg_count': 724, 'polarity': 0.5316946959896507, 'pos_count': 822},
#  'lotr': {'neg_count': 15, 'polarity': 0.6052631578947368, 'pos_count': 23},
#  'war': {'neg_count': 1519, 'polarity': 0.6665203073545555, 'pos_count': 3036},
#  'matrix': {'neg_count': 156,
#   'polarity': 0.46206896551724136,
#   'pos_count': 134},
#  'example': {'neg_count': 1588,
#   'polarity': 0.43946346629015176,
#   'pos_count': 1245},
#  'ghost': {'neg_count': 651, 'polarity': 0.3898781630740394, 'pos_count': 416},
#  'final': {'neg_count': 1188,
#   'polarity': 0.5381026438569206,
#   'pos_count': 1384},
#  'yoda': {'neg_count': 9, 'polarity': 0.6785714285714286, 'pos_count': 19},
#  'obee': {'neg_count': 1, 'polarity': 0.0, 'pos_count': 0},
#  'vader': {'neg_count': 23, 'polarity': 0.6805555555555556, 'pos_count': 49},
#  'spider': {'neg_count': 108, 'polarity': 0.2894736842105263, 'pos_count': 44},
#  'begin': {'neg_count': 2767,
#   'polarity': 0.5306987788331072,
#   'pos_count': 3129},
#  'frodo': {'neg_count': 9, 'polarity': 0.6666666666666666, 'pos_count': 18},
#  'attack': {'neg_count': 871,
#   'polarity': 0.40707964601769914,
#   'pos_count': 598},
#  'return': {'neg_count': 911,
#   'polarity': 0.5859090909090909,
#   'pos_count': 1289},
#  'king': {'neg_count': 766, 'polarity': 0.5579919215233698, 'pos_count': 967},
#  'elijah': {'neg_count': 18, 'polarity': 0.7777777777777778, 'pos_count': 63},
#  'wood': {'neg_count': 815, 'polarity': 0.35978004713275724, 'pos_count': 458},
#  'victim': {'neg_count': 830,
#   'polarity': 0.4283746556473829,
#   'pos_count': 622},
#  'wait': {'neg_count': 1422,
#   'polarity': 0.44905075552111584,
#   'pos_count': 1159},
#  'hypnotizes': {'neg_count': 4,
#   'polarity': 0.42857142857142855,
#   'pos_count': 3},
#  'sting': {'neg_count': 32, 'polarity': 0.5492957746478874, 'pos_count': 39},
#  'wrap': {'neg_count': 164, 'polarity': 0.5567567567567567, 'pos_count': 206},
#  'uh': {'neg_count': 95, 'polarity': 0.20168067226890757, 'pos_count': 24},
#  'hello': {'neg_count': 100, 'polarity': 0.35064935064935066, 'pos_count': 54},
#  'v': {'neg_count': 266, 'polarity': 0.5632183908045977, 'pos_count': 343},
#  'terminator': {'neg_count': 82,
#   'polarity': 0.32786885245901637,
#   'pos_count': 40},
#  'someone': {'neg_count': 2806,
#   'polarity': 0.36943820224719104,
#   'pos_count': 1644},
#  'nazi': {'neg_count': 148, 'polarity': 0.6115485564304461, 'pos_count': 233},
#  'juvenile': {'neg_count': 131,
#   'polarity': 0.4018264840182648,
#   'pos_count': 88},
#  'rush': {'neg_count': 271, 'polarity': 0.5295138888888888, 'pos_count': 305},
#  'conclusion': {'neg_count': 503,
#   'polarity': 0.472193074501574,
#   'pos_count': 450},
#  'adult': {'neg_count': 593, 'polarity': 0.6004043126684636, 'pos_count': 891},
#  'either': {'neg_count': 2227,
#   'polarity': 0.3631684300829282,
#   'pos_count': 1270},
#  'disappointment': {'neg_count': 604,
#   'polarity': 0.24025157232704403,
#   'pos_count': 191},
#  'save': {'neg_count': 2243, 'polarity': 0.3072884496602841, 'pos_count': 995},
#  'remember': {'neg_count': 1559,
#   'polarity': 0.5777356446370531,
#   'pos_count': 2133},
#  'cinema': {'neg_count': 1163,
#   'polarity': 0.5893361581920904,
#   'pos_count': 1669},
#  'dark': {'neg_count': 1100,
#   'polarity': 0.5845921450151057,
#   'pos_count': 1548},
#  'nervous': {'neg_count': 70,
#   'polarity': 0.5906432748538012,
#   'pos_count': 101},
#  '74/75': {'neg_count': 0, 'polarity': 1.0, 'pos_count': 1},
#  'dad': {'neg_count': 396, 'polarity': 0.5330188679245284, 'pos_count': 452},
#  'sister': {'neg_count': 744,
#   'polarity': 0.6112852664576802,
#   'pos_count': 1170},
#  'newbury': {'neg_count': 0, 'polarity': 1.0, 'pos_count': 2},
#  'berkshire': {'neg_count': 0, 'polarity': 1.0, 'pos_count': 3},
#  'england': {'neg_count': 173,
#   'polarity': 0.6704761904761904,
#   'pos_count': 352},
#  'tiger': {'neg_count': 68, 'polarity': 0.6344086021505376, 'pos_count': 118},
#  'snow': {'neg_count': 163, 'polarity': 0.445578231292517, 'pos_count': 131},
#  'appearance': {'neg_count': 492,
#   'polarity': 0.5469613259668509,
#   'pos_count': 594},
#  'grizzly': {'neg_count': 10, 'polarity': 0.6, 'pos_count': 15},
#  'adam': {'neg_count': 285, 'polarity': 0.5567651632970451, 'pos_count': 358},
#  'dan': {'neg_count': 162, 'polarity': 0.6359550561797753, 'pos_count': 283},
#  'haggery': {'neg_count': 0, 'polarity': 1.0, 'pos_count': 1},
#  'dy': {'neg_count': 160, 'polarity': 0.3916349809885932, 'pos_count': 103},
#  'anyone': {'neg_count': 2778,
#   'polarity': 0.46246130030959753,
#   'pos_count': 2390},
#  'dvd': {'neg_count': 1835, 'polarity': 0.6085750853242321, 'pos_count': 2853},
#  'etc': {'neg_count': 1276,
#   'polarity': 0.44255133245958933,
#   'pos_count': 1013},
#  'please': {'neg_count': 1348,
#   'polarity': 0.38306636155606405,
#   'pos_count': 837},
#  'know.the': {'neg_count': 1, 'polarity': 0.5, 'pos_count': 1},
#  'fitness': {'neg_count': 5, 'polarity': 0.5454545454545454, 'pos_count': 6},
#  'club': {'neg_count': 402, 'polarity': 0.5219976218787158, 'pos_count': 439},
#  'shame': {'neg_count': 770, 'polarity': 0.4214876033057851, 'pos_count': 561},
#  'near': {'neg_count': 830, 'polarity': 0.4641704325371207, 'pos_count': 719},
#  '20': {'neg_count': 705, 'polarity': 0.4431279620853081, 'pos_count': 561},
#  'hear': {'neg_count': 1530,
#   'polarity': 0.4884653961885657,
#   'pos_count': 1461},
#  'others': {'neg_count': 1233,
#   'polarity': 0.5922619047619048,
#   'pos_count': 1791},
#  'stinker': {'neg_count': 231,
#   'polarity': 0.04938271604938271,
#   'pos_count': 12},
#  'nominate': {'neg_count': 79,
#   'polarity': 0.7569230769230769,
#   'pos_count': 246},
#  'golden': {'neg_count': 172,
#   'polarity': 0.6742424242424242,
#   'pos_count': 356},
#  'globe': {'neg_count': 29, 'polarity': 0.7883211678832117, 'pos_count': 108},
#  'female': {'neg_count': 1108,
#   'polarity': 0.41591987348444914,
#   'pos_count': 789},
#  'renaissance': {'neg_count': 24,
#   'polarity': 0.7142857142857143,
#   'pos_count': 60},
#  'painter': {'neg_count': 42, 'polarity': 0.6888888888888889, 'pos_count': 93},
#  'mangle': {'neg_count': 30, 'polarity': 0.23076923076923078, 'pos_count': 9},
#  'recognition': {'neg_count': 56,
#   'polarity': 0.7307692307692307,
#   'pos_count': 152},
#  'complaint': {'neg_count': 104,
#   'polarity': 0.7158469945355191,
#   'pos_count': 262},
#  'liberty': {'neg_count': 56,
#   'polarity': 0.6836158192090396,
#   'pos_count': 121},
#  'facts': {'neg_count': 25, 'polarity': 0.4318181818181818, 'pos_count': 19},
#  'perfectly': {'neg_count': 289,
#   'polarity': 0.765040650406504,
#   'pos_count': 941},
#  'fine': {'neg_count': 965, 'polarity': 0.6650468587296078, 'pos_count': 1916},
#  'account': {'neg_count': 242,
#   'polarity': 0.5130784708249497,
#   'pos_count': 255},
#  'artist': {'neg_count': 301,
#   'polarity': 0.6338199513381995,
#   'pos_count': 521},
#  'dishwater-dull': {'neg_count': 1, 'polarity': 0.0, 'pos_count': 0},
#  'script': {'neg_count': 4213,
#   'polarity': 0.31695849546044097,
#   'pos_count': 1955},
#  'enough': {'neg_count': 3787,
#   'polarity': 0.42629904559915166,
#   'pos_count': 2814},
#  'naked': {'neg_count': 506, 'polarity': 0.3690773067331671, 'pos_count': 296},
#  'factual': {'neg_count': 56,
#   'polarity': 0.43434343434343436,
#   'pos_count': 43},
#  'hurriedly': {'neg_count': 9, 'polarity': 0.25, 'pos_count': 3},
#  'cap': {'neg_count': 67, 'polarity': 0.45528455284552843, 'pos_count': 56},
#  'summary': {'neg_count': 214,
#   'polarity': 0.41847826086956524,
#   'pos_count': 154},
#  'couple': {'neg_count': 1944,
#   'polarity': 0.46593406593406594,
#   'pos_count': 1696},
#  'hour': {'neg_count': 2519,
#   'polarity': 0.35558966487592736,
#   'pos_count': 1390},
#  'favor': {'neg_count': 351, 'polarity': 0.3641304347826087, 'pos_count': 201},
#  'brevity': {'neg_count': 10, 'polarity': 0.5238095238095238, 'pos_count': 11},
#  'sequel': {'neg_count': 1263,
#   'polarity': 0.3415015641293014,
#   'pos_count': 655},
#  'surprise': {'neg_count': 1057,
#   'polarity': 0.6005291005291006,
#   'pos_count': 1589},
#  '1990s': {'neg_count': 53, 'polarity': 0.4536082474226804, 'pos_count': 44},
#  'glut': {'neg_count': 4, 'polarity': 0.6363636363636364, 'pos_count': 7},
#  "'die": {'neg_count': 1, 'polarity': 0.875, 'pos_count': 7},
#  'cash': {'neg_count': 312, 'polarity': 0.3389830508474576, 'pos_count': 160},
#  'wrong': {'neg_count': 2199,
#   'polarity': 0.366099740559239,
#   'pos_count': 1270},
#  'guy': {'neg_count': 5343,
#   'polarity': 0.37893757991398347,
#   'pos_count': 3260},
#  'concept': {'neg_count': 641,
#   'polarity': 0.40921658986175113,
#   'pos_count': 444},
#  'cliffhanger': {'neg_count': 27,
#   'polarity': 0.6447368421052632,
#   'pos_count': 49},
#  'mountain': {'neg_count': 241,
#   'polarity': 0.5400763358778626,
#   'pos_count': 283},
#  'rescue': {'neg_count': 370,
#   'polarity': 0.4427710843373494,
#   'pos_count': 294},
#  'sly': {'neg_count': 40, 'polarity': 0.5918367346938775, 'pos_count': 58},
#  "'stop": {'neg_count': 3, 'polarity': 0.5714285714285714, 'pos_count': 4},
#  'stallone': {'neg_count': 61, 'polarity': 0.5234375, 'pos_count': 67},
#  'nit-pickers': {'neg_count': 1, 'polarity': 0.5, 'pos_count': 1},
#  'dream': {'neg_count': 681, 'polarity': 0.637187000532765, 'pos_count': 1196},
#  'especially': {'neg_count': 1789,
#   'polarity': 0.6257322175732217,
#   'pos_count': 2991},
#  'expert': {'neg_count': 192, 'polarity': 0.488, 'pos_count': 183},
#  'climb': {'neg_count': 101, 'polarity': 0.5589519650655022, 'pos_count': 128},
#  'base-jumping': {'neg_count': 0, 'polarity': 1.0, 'pos_count': 1},
#  'aviation': {'neg_count': 10,
#   'polarity': 0.6551724137931034,
#   'pos_count': 19},
#  'facial': {'neg_count': 152,
#   'polarity': 0.5351681957186545,
#   'pos_count': 175},
#  'expression': {'neg_count': 272,
#   'polarity': 0.5821812596006144,
#   'pos_count': 379},
#  'full': {'neg_count': 1473,
#   'polarity': 0.5414072229140723,
#   'pos_count': 1739},
#  'excuse': {'neg_count': 719,
#   'polarity': 0.20288248337028825,
#   'pos_count': 183},
#  'dismiss': {'neg_count': 44,
#   'polarity': 0.7232704402515723,
#   'pos_count': 115},
#  'overblown': {'neg_count': 58,
#   'polarity': 0.44761904761904764,
#   'pos_count': 47},
#  'pile': {'neg_count': 346, 'polarity': 0.17814726840855108, 'pos_count': 75},
#  'junk': {'neg_count': 293, 'polarity': 0.19060773480662985, 'pos_count': 69},
#  'out-acted': {'neg_count': 4,
#   'polarity': 0.42857142857142855,
#   'pos_count': 3},
#  'horse': {'neg_count': 375, 'polarity': 0.5546318289786223, 'pos_count': 467},
#  'lovable': {'neg_count': 82, 'polarity': 0.712280701754386, 'pos_count': 203},
#  'undeniably': {'neg_count': 45,
#   'polarity': 0.5544554455445545,
#   'pos_count': 56},
#  'entertain': {'neg_count': 1109,
#   'polarity': 0.586039567002613,
#   'pos_count': 1570},
#  'romp': {'neg_count': 66, 'polarity': 0.6094674556213018, 'pos_count': 103},
#  'plenty': {'neg_count': 478,
#   'polarity': 0.5886402753872634,
#   'pos_count': 684},
#  'unintentionally': {'neg_count': 200,
#   'polarity': 0.1836734693877551,
#   'pos_count': 45},
#  'john': {'neg_count': 1627,
#   'polarity': 0.5998524348253812,
#   'pos_count': 2439},
#  'lithgows': {'neg_count': 0, 'polarity': 1.0, 'pos_count': 1},
#  'sneery': {'neg_count': 0, 'polarity': 1.0, 'pos_count': 2},
#  'evilness': {'neg_count': 3, 'polarity': 0.6666666666666666, 'pos_count': 6},
#  'tick': {'neg_count': 60, 'polarity': 0.4690265486725664, 'pos_count': 53},
#  'box': {'neg_count': 776, 'polarity': 0.45042492917847027, 'pos_count': 636},
#  'baddie': {'neg_count': 88, 'polarity': 0.41721854304635764, 'pos_count': 63},
#  'permanently': {'neg_count': 30,
#   'polarity': 0.4827586206896552,
#   'pos_count': 28},
#  'harass': {'neg_count': 46, 'polarity': 0.4177215189873418, 'pos_count': 33},
#  'hapless': {'neg_count': 61, 'polarity': 0.5, 'pos_count': 61},
#  "'turncoat": {'neg_count': 0, 'polarity': 1.0, 'pos_count': 1},
#  'agent': {'neg_count': 472, 'polarity': 0.4830230010952902, 'pos_count': 441},
#  'rex': {'neg_count': 66, 'polarity': 0.56, 'pos_count': 84},
#  ...}

# %% [markdown]
# # Testing the generated sentiment lexicon

# %%
def get_single_text_polarity(input_data, input_idx, sentiment_lexicon):
    
    text = TextBlob(input_data[input_idx][0]).lower().words

    # filter stop words
    filtered_text = [word for word in text if not word in stopwords_eng]

    # lemmatize the text
    lemmatized_filtered_text = TextBlob(lemmatize_with_postag(" ".join(filtered_text)))
    
    polarity_sum = 0
    word_count = 0
    for word in lemmatized_filtered_text.words:
        if word in sentiment_lexicon:
            polarity = sentiment_lexicon[word]['polarity']
            polarity_sum += polarity
            word_count += 1

    text_polarity = polarity_sum / word_count
#     print("Text polarity: %.2f" % text_polarity)
    return text_polarity

# %%
def calculate_accuracy(test_data, sentiment_lexicon):
    polarity_match_count = 0
    idx = 0
    for elem in test_data:
        calculated_polarity = get_single_text_polarity(test_data, idx, sentiment_lexicon)
        polarity_str = elem[1]

        if polarity_str == 'negative':
            polarity = 0
        else:
            polarity = 1

        if calculated_polarity > 0.5:
            predicted_polarity = 1
            if predicted_polarity == polarity:
                polarity_match_count += 1
        elif calculated_polarity < 0.5:
            predicted_polarity = 0
            if predicted_polarity == polarity:
                polarity_match_count += 1

        idx += 1
        
        acc = polarity_match_count / len(test_data)
    print("Accuracy: %.2f%% \n  %d / %d = %.2f" % (acc*100, polarity_match_count, len(test_data), acc) )
    
    return acc

# %%
test_data = read_csv_data('IMDB_data_last_2000rows')
calculate_accuracy(test_data, sentiment_lexicon)
# Out:
# Accuracy: 85.00%
#   1700 / 2000 = 0.85
# 0.85

# %%
def get_text_polarity(input_data, sentiment_lexicon):
    text = TextBlob(input_data).lower().words

    # filter stop words
    filtered_text = [word for word in text if not word in stopwords_eng]

    # lemmatize the text
    lemmatized_filtered_text = TextBlob(lemmatize_with_postag(" ".join(filtered_text)))
    
    polarity_sum = 0
    word_count = 0
    for word in lemmatized_filtered_text.words:
        if word in sentiment_lexicon:
            polarity = sentiment_lexicon[word]['polarity']
            polarity_sum += polarity
            word_count += 1
            
    if word_count == 0:
        return 0.5

    text_polarity = polarity_sum / word_count
#     print("Text polarity: %.2f" % text_polarity)
    return text_polarity

# %%
some_texts = [
    'That was an interesting assignment, I think the generated sentiment lexicon is slightly racist and has a lot of prejudice.',
    'That was a fun assignment, I think the generated sentiment lexicon is slightly racist and has a lot of prejudice.',
    'That was a fun assignment, I think the generated lexicon is slightly racist and has a lot of prejudice.',
    'That was a fun assignment, I think the generated lexicon is slightly racist.',
    'Black',
    'White',
    'Latino', # yeah, this is the racist part (polarity is 0.2753)
    'Alright',
    'Right',
    'Perfect',
    'imperfect',
    'terrible',
    'An absolutely terrible movie.',
    'terrific',
    'A terrific performance.',
    'virus',
    'antivirus',
    'prejudice',
    'racism',
    'racist',
    'university',
    'computer',
    'science',
    'language',
    'natural language processing',
    'The perfect example.',
    'This is the perfect example, but it cannot get a perfect score.',
    'This is the perfect example, but it can\'t get a perfect score.',
    'This is the perfect example, it can get a perfect score.',
    'This is the worst example, it can\'t get a perfect score.',
    'This is the worst example, it\'s going to get a terrible score.',
    'The sky is blue',
    'The sun is shining.',
    'The sun is shining. This should get a very positive score.',
    'Human emotions are complicated.',
    'Human emotions are complicated for computers.',
    'Human emotions are complicated for humans',
    'Beauty doesn\'t rhyme well with an empty mind.',
    'Beauty does rhyme well with an empty mind.',
    'To be or not to be', # I guess every word is a stopword in this sentence
    'Comparison is the thief of self worth.',
    
    # and now try some real (Tesla V100) reviews 
    'Very nice upgrade from my Nvidia Riva TNT. Roller Coaster Tycoon ran at 3000fps at 360p.'
    'Solitaire at max settings ran at an outstanding 6000fps. Unfortunately my monitor had massive screen'
    'tearing and I misplayed as the mouse was not keeping up. The cards flickered like a candle as they'
    'floated across the screen. My CRT monitor glass turned black from the unbelievable frame rate before'
    'bursting into flames. I then upgraded my monitor to 240hz and you would not believe it, I can now see'
    'the air molecules pushing back on the cards as I move them from the Tableaux to their foundation homes.'
    'Words cannot describe the winning cascade. It was visually stunning; more so than Iguazu Falls itself.'
    'Simply tremendous! This GPU is the future of Solitaire and I will be recommending it at worlds in Helsinki. ',
    'You don\'t need a monitor.'
    'I was able to finally use those $1,800.00 HDMI Gold cables and plug them directly into my cerebral cortex. ',
    
    # and Rotten Tomatoes reviews (for Whiplash)
    'It all ends on a triumphantly upbeat note that has the intensity to completely'
    'dominate every annoyance and dubious direction that came before it.',
    
    'What makes musical genius? Is it inherent, or does it have to be dragged'
    'kicking, screaming and bleeding from you? ' # that was a 4.5/5 review but it got a 'negative' polarity (0.4846)
]

for text in some_texts:
    print("%.4f -> %s" % (get_text_polarity(text, sentiment_lexicon), text))
# Out:
# 0.5322 -> That was an interesting assignment, I think the generated sentiment lexicon is slightly racist and has a lot of prejudice.
# 0.5480 -> That was a fun assignment, I think the generated sentiment lexicon is slightly racist and has a lot of prejudice.
# 0.5518 -> That was a fun assignment, I think the generated lexicon is slightly racist and has a lot of prejudice.
# 0.5424 -> That was a fun assignment, I think the generated lexicon is slightly racist.
# 0.5021 -> Black
# 0.5103 -> White
# 0.2754 -> Latino
# 0.2451 -> Alright
# 0.5125 -> Right
# 0.7717 -> Perfect
# 0.8000 -> imperfect
# 0.1270 -> terrible
# 0.3321 -> An absolutely terrible movie.
# 0.8172 -> terrific
# 0.7422 -> A terrific performance.
# 0.2675 -> virus
# 1.0000 -> antivirus
# 0.6461 -> prejudice
# 0.4894 -> racism
# 0.3588 -> racist
# 0.4958 -> university
# 0.3626 -> computer
# 0.4502 -> science
# 0.5906 -> language
# 0.5943 -> natural language processing
# 0.6056 -> The perfect example.
# 0.6105 -> This is the perfect example, but it cannot get a perfect score.
# 0.5518 -> This is the perfect example, but it can't get a perfect score.
# 0.6105 -> This is the perfect example, it can get a perfect score.
# 0.4543 -> This is the worst example, it can't get a perfect score.
# 0.3786 -> This is the worst example, it's going to get a terrible score.
# 0.6135 -> The sky is blue
# 0.5544 -> The sun is shining.
# 0.5063 -> The sun is shining. This should get a very positive score.
# 0.6310 -> Human emotions are complicated.
# 0.5639 -> Human emotions are complicated for computers.
# 0.6271 -> Human emotions are complicated for humans
# 0.4707 -> Beauty doesn't rhyme well with an empty mind.
# 0.4845 -> Beauty does rhyme well with an empty mind.
# 0.5000 -> To be or not to be
# 0.5530 -> Comparison is the thief of self worth.
# 0.5442 -> Very nice upgrade from my Nvidia Riva TNT. Roller Coaster Tycoon ran at 3000fps at 360p.Solitaire at max settings ran at an outstanding 6000fps. Unfortunately my monitor had massive screentearing and I misplayed as the mouse was not keeping up. The cards flickered like a candle as theyfloated across the screen. My CRT monitor glass turned black from the unbelievable frame rate beforebursting into flames. I then upgraded my monitor to 240hz and you would not believe it, I can now seethe air molecules pushing back on the cards as I move them from the Tableaux to their foundation homes.Words cannot describe the winning cascade. It was visually stunning; more so than Iguazu Falls itself.Simply tremendous! This GPU is the future of Solitaire and I will be recommending it at worlds in Helsinki.
# 0.5014 -> You don't need a monitor.I was able to finally use those $1,800.00 HDMI Gold cables and plug them directly into my cerebral cortex.
# 0.5235 -> It all ends on a triumphantly upbeat note that has the intensity to completelydominate every annoyance and dubious direction that came before it.
# 0.4846 -> What makes musical genius? Is it inherent, or does it have to be draggedkicking, screaming and bleeding from you?
